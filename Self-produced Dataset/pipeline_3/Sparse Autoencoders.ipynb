# %% [markdown]
# https://www.datacamp.com/tutorial/autoencoder-keras-tutorial

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D
from keras.models import Model
from keras.optimizers import RMSprop
from keras import regularizers, layers
import keras
import tensorflow as tf
from tensorflow import keras
from keras import layers
import matplotlib.pyplot as plt

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load Dataset
train_df = pd.read_csv("/content/drive/MyDrive/24-25 Academic Year/CS156/Second Pipeline/0. Dataset/augmented_data.csv")
test_df = pd.read_csv("/content/drive/MyDrive/24-25 Academic Year/CS156/Second Pipeline/0. Dataset/test_data.csv")
val_df = pd.read_csv("/content/drive/MyDrive/24-25 Academic Year/CS156/Second Pipeline/0. Dataset/val_data.csv")

# %%
# Train
x_train = train_df.drop(['label'], axis=1).values.astype('float32')
y_train = train_df['label'].values

# %%
# Val
x_val = val_df.drop(['label'], axis=1).values.astype('float32')
y_val = val_df['label'].values

# %%
# Test
x_test = test_df.drop(['label'], axis=1).values.astype('float32')
y_test = test_df['label'].values

# %%
# Check shape
x_train.shape
# Out:
# (9240, 4096)

# %%
tf.keras.mixed_precision.set_global_policy('float32')

# Define model parameters
encoding_dim = 32
input_shape = 4096

# Build the model - keeping only the necessary dtype specifications
input_img = keras.Input(shape=(input_shape,), dtype='float32', name='input_layer')

encoded = layers.Dense(
    encoding_dim,
    activation='relu',
    dtype='float32',
    activity_regularizer=regularizers.l1(1e-5),
    name='encoder'
)(input_img)

decoded = layers.Dense(
    input_shape,
    activation='sigmoid',
    dtype='float32',
    name='decoder'
)(encoded)

# Create the autoencoder model
autoencoder = keras.Model(input_img, decoded, name='autoencoder')

# Standard compilation
autoencoder.compile(
    optimizer='adam',
    loss='binary_crossentropy'
)

# %%
history = autoencoder.fit(x_train, x_train,
                epochs=200,
                batch_size=256,
                shuffle=True,
                validation_data=(x_val, x_val))
# Out:
# Epoch 1/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.3215 - val_loss: 0.3052
# Epoch 2/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3196 - val_loss: 0.3047
# Epoch 3/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.3193 - val_loss: 0.3042
# Epoch 4/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3186 - val_loss: 0.3038
# Epoch 5/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.3184 - val_loss: 0.3033
# Epoch 6/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3179 - val_loss: 0.3029
# Epoch 7/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.3177 - val_loss: 0.3024
# Epoch 8/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3185 - val_loss: 0.3020
# Epoch 9/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.3175 - val_loss: 0.3016
# Epoch 10/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.3156 - val_loss: 0.3012
# Epoch 11/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.3170 - val_loss: 0.3008
# Epoch 12/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.3154 - val_loss: 0.3005
# Epoch 13/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.3158 - val_loss: 0.3001
# Epoch 14/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.3154 - val_loss: 0.2998
# Epoch 15/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3158 - val_loss: 0.2994
# Epoch 16/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3163 - val_loss: 0.2991
# Epoch 17/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.3144 - val_loss: 0.2988
# Epoch 18/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.3155 - val_loss: 0.2985
# Epoch 19/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3153 - val_loss: 0.2981
# Epoch 20/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.3137 - val_loss: 0.2978
# Epoch 21/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.3147 - val_loss: 0.2975
# Epoch 22/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 0.3141 - val_loss: 0.2972
# Epoch 23/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.3145 - val_loss: 0.2969
# Epoch 24/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.3136 - val_loss: 0.2967
# Epoch 25/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3133 - val_loss: 0.2964
# Epoch 26/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.3145 - val_loss: 0.2961
# Epoch 27/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.3132 - val_loss: 0.2959
# Epoch 28/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.3122 - val_loss: 0.2956
# Epoch 29/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.3133 - val_loss: 0.2954
# Epoch 30/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.3136 - val_loss: 0.2952
# Epoch 31/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3136 - val_loss: 0.2949
# Epoch 32/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.3127 - val_loss: 0.2947
# Epoch 33/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.3122 - val_loss: 0.2945
# Epoch 34/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.3120 - val_loss: 0.2943
# Epoch 35/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.3115 - val_loss: 0.2940
# Epoch 36/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.3109 - val_loss: 0.2938
# Epoch 37/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3104 - val_loss: 0.2936
# Epoch 38/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3109 - val_loss: 0.2934
# Epoch 39/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3099 - val_loss: 0.2933
# Epoch 40/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.3106 - val_loss: 0.2931
# Epoch 41/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3105 - val_loss: 0.2929
# Epoch 42/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.3091 - val_loss: 0.2927
# Epoch 43/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.3091 - val_loss: 0.2925
# Epoch 44/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.3090 - val_loss: 0.2924
# Epoch 45/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.3097 - val_loss: 0.2922
# Epoch 46/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3106 - val_loss: 0.2920
# Epoch 47/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.3108 - val_loss: 0.2918
# Epoch 48/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.3103 - val_loss: 0.2917
# Epoch 49/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.3105 - val_loss: 0.2916
# Epoch 50/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.3073 - val_loss: 0.2914
# Epoch 51/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.3102 - val_loss: 0.2913
# Epoch 52/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3101 - val_loss: 0.2911
# Epoch 53/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3087 - val_loss: 0.2910
# Epoch 54/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3090 - val_loss: 0.2909
# Epoch 55/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.3080 - val_loss: 0.2907
# Epoch 56/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.3090 - val_loss: 0.2906
# Epoch 57/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.3089 - val_loss: 0.2905
# Epoch 58/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.3088 - val_loss: 0.2903
# Epoch 59/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3085 - val_loss: 0.2902
# Epoch 60/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.3090 - val_loss: 0.2901
# Epoch 61/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3096 - val_loss: 0.2900
# Epoch 62/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3083 - val_loss: 0.2899
# Epoch 63/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.3081 - val_loss: 0.2898
# Epoch 64/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.3081 - val_loss: 0.2897
# Epoch 65/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.3085 - val_loss: 0.2896
# Epoch 66/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.3086 - val_loss: 0.2895
# Epoch 67/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3082 - val_loss: 0.2894
# Epoch 68/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.3083 - val_loss: 0.2893
# Epoch 69/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.3086 - val_loss: 0.2892
# Epoch 70/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3089 - val_loss: 0.2891
# Epoch 71/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.3087 - val_loss: 0.2890
# Epoch 72/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.3082 - val_loss: 0.2889
# Epoch 73/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.3075 - val_loss: 0.2888
# Epoch 74/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3070 - val_loss: 0.2887
# Epoch 75/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3088 - val_loss: 0.2887
# Epoch 76/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3072 - val_loss: 0.2886
# Epoch 77/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.3078 - val_loss: 0.2885
# Epoch 78/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.3080 - val_loss: 0.2884
# Epoch 79/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.3067 - val_loss: 0.2883
# Epoch 80/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.3065 - val_loss: 0.2883
# Epoch 81/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.3078 - val_loss: 0.2882
# Epoch 82/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3088 - val_loss: 0.2882
# Epoch 83/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.3083 - val_loss: 0.2881
# Epoch 84/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3080 - val_loss: 0.2880
# Epoch 85/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.3082 - val_loss: 0.2879
# Epoch 86/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.3068 - val_loss: 0.2879
# Epoch 87/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.3079 - val_loss: 0.2878
# Epoch 88/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.3066 - val_loss: 0.2877
# Epoch 89/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3076 - val_loss: 0.2877
# Epoch 90/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3080 - val_loss: 0.2876
# Epoch 91/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.3068 - val_loss: 0.2876
# Epoch 92/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.3086 - val_loss: 0.2875
# Epoch 93/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.3066 - val_loss: 0.2874
# Epoch 94/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.3074 - val_loss: 0.2874
# Epoch 95/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.3072 - val_loss: 0.2873
# Epoch 96/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3067 - val_loss: 0.2872
# Epoch 97/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.3068 - val_loss: 0.2872
# Epoch 98/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.3081 - val_loss: 0.2872
# Epoch 99/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.3079 - val_loss: 0.2871
# Epoch 100/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 0.3071 - val_loss: 0.2871
# Epoch 101/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.3064 - val_loss: 0.2870
# Epoch 102/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3072 - val_loss: 0.2870
# Epoch 103/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.3077 - val_loss: 0.2870
# Epoch 104/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.3070 - val_loss: 0.2869
# Epoch 105/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.3078 - val_loss: 0.2869
# Epoch 106/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.3059 - val_loss: 0.2869
# Epoch 107/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.3074 - val_loss: 0.2868
# Epoch 108/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3075 - val_loss: 0.2868
# Epoch 109/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.3063 - val_loss: 0.2867
# Epoch 110/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.3073 - val_loss: 0.2867
# Epoch 111/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3074 - val_loss: 0.2866
# Epoch 112/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.3077 - val_loss: 0.2866
# Epoch 113/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.3079 - val_loss: 0.2866
# Epoch 114/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.3062 - val_loss: 0.2866
# Epoch 115/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.3069 - val_loss: 0.2865
# Epoch 116/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.3058 - val_loss: 0.2865
# Epoch 117/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.3064 - val_loss: 0.2864
# Epoch 118/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.3066 - val_loss: 0.2864
# Epoch 119/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.3062 - val_loss: 0.2863
# Epoch 120/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.3068 - val_loss: 0.2863
# Epoch 121/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3074 - val_loss: 0.2862
# Epoch 122/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3063 - val_loss: 0.2862
# Epoch 123/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.3057 - val_loss: 0.2862
# Epoch 124/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.3075 - val_loss: 0.2862
# Epoch 125/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.3062 - val_loss: 0.2861
# Epoch 126/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 0.3066 - val_loss: 0.2861
# Epoch 127/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.3057 - val_loss: 0.2860
# Epoch 128/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3076 - val_loss: 0.2860
# Epoch 129/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3066 - val_loss: 0.2860
# Epoch 130/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3055 - val_loss: 0.2860
# Epoch 131/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3057 - val_loss: 0.2860
# Epoch 132/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.3064 - val_loss: 0.2860
# Epoch 133/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.3066 - val_loss: 0.2860
# Epoch 134/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.3084 - val_loss: 0.2860
# Epoch 135/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.3054 - val_loss: 0.2859
# Epoch 136/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.3082 - val_loss: 0.2859
# Epoch 137/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.3071 - val_loss: 0.2859
# Epoch 138/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3057 - val_loss: 0.2859
# Epoch 139/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.3075 - val_loss: 0.2858
# Epoch 140/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3050 - val_loss: 0.2858
# Epoch 141/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.3067 - val_loss: 0.2858
# Epoch 142/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.3074 - val_loss: 0.2858
# Epoch 143/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.3065 - val_loss: 0.2857
# Epoch 144/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3070 - val_loss: 0.2857
# Epoch 145/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3063 - val_loss: 0.2857
# Epoch 146/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3059 - val_loss: 0.2857
# Epoch 147/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.3070 - val_loss: 0.2857
# Epoch 148/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.3063 - val_loss: 0.2857
# Epoch 149/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.3054 - val_loss: 0.2857
# Epoch 150/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.3058 - val_loss: 0.2856
# Epoch 151/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.3065 - val_loss: 0.2856
# Epoch 152/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3062 - val_loss: 0.2856
# Epoch 153/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3057 - val_loss: 0.2856
# Epoch 154/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3064 - val_loss: 0.2856
# Epoch 155/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3056 - val_loss: 0.2856
# Epoch 156/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 0.3062 - val_loss: 0.2855
# Epoch 157/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.3075 - val_loss: 0.2855
# Epoch 158/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.3048 - val_loss: 0.2855
# Epoch 159/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3057 - val_loss: 0.2855
# Epoch 160/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3071 - val_loss: 0.2855
# Epoch 161/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.3069 - val_loss: 0.2855
# Epoch 162/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3080 - val_loss: 0.2855
# Epoch 163/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.3074 - val_loss: 0.2854
# Epoch 164/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.3067 - val_loss: 0.2854
# Epoch 165/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.3065 - val_loss: 0.2854
# Epoch 166/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3058 - val_loss: 0.2854
# Epoch 167/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.3065 - val_loss: 0.2854
# Epoch 168/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3066 - val_loss: 0.2854
# Epoch 169/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.3063 - val_loss: 0.2854
# Epoch 170/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.3050 - val_loss: 0.2854
# Epoch 171/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.3058 - val_loss: 0.2854
# Epoch 172/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.3056 - val_loss: 0.2854
# Epoch 173/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.3047 - val_loss: 0.2853
# Epoch 174/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3068 - val_loss: 0.2853
# Epoch 175/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3071 - val_loss: 0.2853
# Epoch 176/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3067 - val_loss: 0.2853
# Epoch 177/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3062 - val_loss: 0.2853
# Epoch 178/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.3072 - val_loss: 0.2853
# Epoch 179/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.3051 - val_loss: 0.2853
# Epoch 180/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.3049 - val_loss: 0.2853
# Epoch 181/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.3056 - val_loss: 0.2853
# Epoch 182/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3058 - val_loss: 0.2853
# Epoch 183/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.3063 - val_loss: 0.2853
# Epoch 184/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.3072 - val_loss: 0.2853
# Epoch 185/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.3074 - val_loss: 0.2852
# Epoch 186/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.3079 - val_loss: 0.2852
# Epoch 187/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.3055 - val_loss: 0.2853
# Epoch 188/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3062 - val_loss: 0.2853
# Epoch 189/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.3067 - val_loss: 0.2852
# Epoch 190/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.3070 - val_loss: 0.2852
# Epoch 191/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.3062 - val_loss: 0.2852
# Epoch 192/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3069 - val_loss: 0.2852
# Epoch 193/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.3051 - val_loss: 0.2852
# Epoch 194/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.3060 - val_loss: 0.2852
# Epoch 195/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.3062 - val_loss: 0.2852
# Epoch 196/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3068 - val_loss: 0.2852
# Epoch 197/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.3060 - val_loss: 0.2852
# Epoch 198/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.3067 - val_loss: 0.2852
# Epoch 199/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3056 - val_loss: 0.2852
# Epoch 200/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3070 - val_loss: 0.2852

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot the loss
epochs = range(1, len(train_loss) + 1)

plt.plot(epochs, train_loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(64, 64))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(64, 64))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
# Set global policy
tf.keras.mixed_precision.set_global_policy('float32')

# Define model parameters
encoding_dim = 32
input_shape = 4096

# Build the model with deeper architecture
input_img = keras.Input(shape=(input_shape,), dtype='float32')

# Encoder
x = layers.Dense(512)(input_img)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

x = layers.Dense(256)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

x = layers.Dense(128)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

encoded = layers.Dense(encoding_dim, activity_regularizer=tf.keras.regularizers.l1(1e-6))(x)
x = layers.BatchNormalization()(encoded)
encoded = layers.Activation('relu')(x)

# Decoder
x = layers.Dense(128)(encoded)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

x = layers.Dense(256)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

x = layers.Dense(512)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

decoded = layers.Dense(input_shape, activation='sigmoid')(x)

# Create the autoencoder model
autoencoder = keras.Model(input_img, decoded)

# Compile model
autoencoder.compile(
   optimizer=keras.optimizers.Adam(learning_rate=0.001),
   loss='binary_crossentropy'
)

# Add callbacks
early_stopping = keras.callbacks.EarlyStopping(
   monitor='val_loss',
   patience=5,
   restore_best_weights=True
)

lr_reducer = keras.callbacks.ReduceLROnPlateau(
   monitor='val_loss',
   factor=0.5,
   patience=3
)

# Train the model
history = autoencoder.fit(
   x_train,
   x_train,
   epochs=100,
   batch_size=32,
   validation_data=(x_val, x_val),
   callbacks=[early_stopping, lr_reducer],
   verbose=1
)

# Plot training history
train_loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(train_loss) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Function to visualize original and reconstructed images
def plot_reconstructions(autoencoder, x_test, n=10):
   # Get reconstructions
   reconstructions = autoencoder.predict(x_test[:n])

   plt.figure(figsize=(20, 4))
   for i in range(n):
       # Original
       ax = plt.subplot(2, n, i + 1)
       plt.imshow(x_test[i].reshape(64, 64), cmap='gray')
       plt.gray()
       ax.get_xaxis().set_visible(False)
       ax.get_yaxis().set_visible(False)

       # Reconstruction
       ax = plt.subplot(2, n, i + n + 1)
       plt.imshow(reconstructions[i].reshape(64, 64), cmap='gray')
       plt.gray()
       ax.get_xaxis().set_visible(False)
       ax.get_yaxis().set_visible(False)
   plt.show()

# Visualize results
plot_reconstructions(autoencoder, x_test)
# Out:
# Epoch 1/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 31s 82ms/step - loss: 0.2888 - val_loss: 0.1687 - learning_rate: 0.0010
# Epoch 2/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 22s 77ms/step - loss: 0.1975 - val_loss: 0.1511 - learning_rate: 0.0010
# Epoch 3/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 24s 82ms/step - loss: 0.1831 - val_loss: 0.1452 - learning_rate: 0.0010
# Epoch 4/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 40s 78ms/step - loss: 0.1742 - val_loss: 0.1342 - learning_rate: 0.0010
# Epoch 5/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 79ms/step - loss: 0.1671 - val_loss: 0.1304 - learning_rate: 0.0010
# Epoch 6/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 23s 80ms/step - loss: 0.1627 - val_loss: 0.1282 - learning_rate: 0.0010
# Epoch 7/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 81ms/step - loss: 0.1599 - val_loss: 0.1250 - learning_rate: 0.0010
# Epoch 8/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - loss: 0.1561 - val_loss: 0.1216 - learning_rate: 0.0010
# Epoch 9/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 40s 80ms/step - loss: 0.1521 - val_loss: 0.1239 - learning_rate: 0.0010
# Epoch 10/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 80ms/step - loss: 0.1491 - val_loss: 0.1190 - learning_rate: 0.0010
# Epoch 11/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 40s 77ms/step - loss: 0.1478 - val_loss: 0.1180 - learning_rate: 0.0010
# Epoch 12/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 77ms/step - loss: 0.1462 - val_loss: 0.1163 - learning_rate: 0.0010
# Epoch 13/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 42s 79ms/step - loss: 0.1431 - val_loss: 0.1152 - learning_rate: 0.0010
# Epoch 14/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 80ms/step - loss: 0.1416 - val_loss: 0.1147 - learning_rate: 0.0010
# Epoch 15/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 40s 78ms/step - loss: 0.1391 - val_loss: 0.1140 - learning_rate: 0.0010
# Epoch 16/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 79ms/step - loss: 0.1393 - val_loss: 0.1141 - learning_rate: 0.0010
# Epoch 17/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 77ms/step - loss: 0.1373 - val_loss: 0.1119 - learning_rate: 0.0010
# Epoch 18/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 77ms/step - loss: 0.1341 - val_loss: 0.1102 - learning_rate: 0.0010
# Epoch 19/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 40s 75ms/step - loss: 0.1360 - val_loss: 0.1119 - learning_rate: 0.0010
# Epoch 20/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 77ms/step - loss: 0.1335 - val_loss: 0.1100 - learning_rate: 0.0010
# Epoch 21/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 77ms/step - loss: 0.1324 - val_loss: 0.1096 - learning_rate: 0.0010
# Epoch 22/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 77ms/step - loss: 0.1314 - val_loss: 0.1080 - learning_rate: 0.0010
# Epoch 23/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 77ms/step - loss: 0.1309 - val_loss: 0.1088 - learning_rate: 0.0010
# Epoch 24/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 78ms/step - loss: 0.1308 - val_loss: 0.1079 - learning_rate: 0.0010
# Epoch 25/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 78ms/step - loss: 0.1295 - val_loss: 0.1066 - learning_rate: 0.0010
# Epoch 26/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 40s 76ms/step - loss: 0.1287 - val_loss: 0.1076 - learning_rate: 0.0010
# Epoch 27/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 77ms/step - loss: 0.1283 - val_loss: 0.1065 - learning_rate: 0.0010
# Epoch 28/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 24s 82ms/step - loss: 0.1269 - val_loss: 0.1061 - learning_rate: 0.0010
# Epoch 29/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - loss: 0.1261 - val_loss: 0.1074 - learning_rate: 0.0010
# Epoch 30/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 22s 77ms/step - loss: 0.1249 - val_loss: 0.1064 - learning_rate: 0.0010
# Epoch 31/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 24s 82ms/step - loss: 0.1240 - val_loss: 0.1076 - learning_rate: 0.0010
# Epoch 32/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 40s 80ms/step - loss: 0.1216 - val_loss: 0.1017 - learning_rate: 5.0000e-04
# Epoch 33/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 40s 77ms/step - loss: 0.1220 - val_loss: 0.1026 - learning_rate: 5.0000e-04
# Epoch 34/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 77ms/step - loss: 0.1208 - val_loss: 0.1024 - learning_rate: 5.0000e-04
# Epoch 35/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 75ms/step - loss: 0.1202 - val_loss: 0.1033 - learning_rate: 5.0000e-04
# Epoch 36/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 24s 82ms/step - loss: 0.1190 - val_loss: 0.1002 - learning_rate: 2.5000e-04
# Epoch 37/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 80ms/step - loss: 0.1184 - val_loss: 0.1002 - learning_rate: 2.5000e-04
# Epoch 38/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 80ms/step - loss: 0.1170 - val_loss: 0.1009 - learning_rate: 2.5000e-04
# Epoch 39/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 79ms/step - loss: 0.1174 - val_loss: 0.1003 - learning_rate: 2.5000e-04
# Epoch 40/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 23s 80ms/step - loss: 0.1159 - val_loss: 0.0996 - learning_rate: 1.2500e-04
# Epoch 41/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 42s 84ms/step - loss: 0.1158 - val_loss: 0.0995 - learning_rate: 1.2500e-04
# Epoch 42/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 40s 80ms/step - loss: 0.1158 - val_loss: 0.0996 - learning_rate: 1.2500e-04
# Epoch 43/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 40s 78ms/step - loss: 0.1164 - val_loss: 0.0993 - learning_rate: 1.2500e-04
# Epoch 44/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 77ms/step - loss: 0.1159 - val_loss: 0.0995 - learning_rate: 1.2500e-04
# Epoch 45/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 77ms/step - loss: 0.1163 - val_loss: 0.0994 - learning_rate: 1.2500e-04
# Epoch 46/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 79ms/step - loss: 0.1151 - val_loss: 0.0994 - learning_rate: 1.2500e-04
# Epoch 47/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 79ms/step - loss: 0.1148 - val_loss: 0.0992 - learning_rate: 6.2500e-05
# Epoch 48/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 42s 81ms/step - loss: 0.1148 - val_loss: 0.0992 - learning_rate: 6.2500e-05
# Epoch 49/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 24s 83ms/step - loss: 0.1153 - val_loss: 0.0991 - learning_rate: 6.2500e-05
# Epoch 50/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 81ms/step - loss: 0.1156 - val_loss: 0.0992 - learning_rate: 6.2500e-05
# Epoch 51/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 81ms/step - loss: 0.1153 - val_loss: 0.0989 - learning_rate: 3.1250e-05
# Epoch 52/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 40s 78ms/step - loss: 0.1157 - val_loss: 0.0990 - learning_rate: 3.1250e-05
# Epoch 53/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 79ms/step - loss: 0.1151 - val_loss: 0.0990 - learning_rate: 3.1250e-05
# Epoch 54/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 79ms/step - loss: 0.1147 - val_loss: 0.0991 - learning_rate: 3.1250e-05
# Epoch 55/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 80ms/step - loss: 0.1137 - val_loss: 0.0989 - learning_rate: 1.5625e-05
# Epoch 56/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 24s 82ms/step - loss: 0.1154 - val_loss: 0.0990 - learning_rate: 1.5625e-05
# Epoch 57/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 42s 84ms/step - loss: 0.1138 - val_loss: 0.0989 - learning_rate: 1.5625e-05
# Epoch 58/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 40s 79ms/step - loss: 0.1145 - val_loss: 0.0989 - learning_rate: 7.8125e-06
# Epoch 59/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 23s 80ms/step - loss: 0.1149 - val_loss: 0.0989 - learning_rate: 7.8125e-06
# Epoch 60/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - loss: 0.1141 - val_loss: 0.0990 - learning_rate: 7.8125e-06
# Epoch 61/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 42s 84ms/step - loss: 0.1146 - val_loss: 0.0988 - learning_rate: 3.9063e-06
# Epoch 62/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 40s 80ms/step - loss: 0.1145 - val_loss: 0.0989 - learning_rate: 3.9063e-06
# Epoch 63/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 24s 81ms/step - loss: 0.1158 - val_loss: 0.0988 - learning_rate: 3.9063e-06
# Epoch 64/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 42s 85ms/step - loss: 0.1151 - val_loss: 0.0989 - learning_rate: 1.9531e-06
# Epoch 65/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 40s 82ms/step - loss: 0.1150 - val_loss: 0.0989 - learning_rate: 1.9531e-06
# Epoch 66/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 40s 79ms/step - loss: 0.1142 - val_loss: 0.0988 - learning_rate: 1.9531e-06
# Epoch 67/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 24s 82ms/step - loss: 0.1140 - val_loss: 0.0988 - learning_rate: 1.9531e-06
# Epoch 68/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 23s 79ms/step - loss: 0.1143 - val_loss: 0.0989 - learning_rate: 1.9531e-06
# Epoch 69/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 24s 84ms/step - loss: 0.1145 - val_loss: 0.0988 - learning_rate: 1.9531e-06
# Epoch 70/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 85ms/step - loss: 0.1141 - val_loss: 0.0989 - learning_rate: 9.7656e-07
# Epoch 71/100
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 41s 86ms/step - loss: 0.1153 - val_loss: 0.0988 - learning_rate: 9.7656e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step

# %%
# Set global policy
tf.keras.mixed_precision.set_global_policy('float32')

# Define model parameters
encoding_dim = 32
input_shape = 4096

# Build the model with deeper architecture
input_img = keras.Input(shape=(input_shape,), dtype='float32')

# Encoder
x = layers.Dense(512)(input_img)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

x = layers.Dense(256)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

x = layers.Dense(128)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

encoded = layers.Dense(encoding_dim, activity_regularizer=tf.keras.regularizers.l1(1e-6))(x)
x = layers.BatchNormalization()(encoded)
encoded = layers.Activation('relu')(x)

# Decoder
x = layers.Dense(128)(encoded)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

x = layers.Dense(256)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

x = layers.Dense(512)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

decoded = layers.Dense(input_shape, activation='sigmoid')(x)

# Create the autoencoder model
autoencoder = keras.Model(input_img, decoded)

# Compile model
autoencoder.compile(
   optimizer=keras.optimizers.Adam(learning_rate=0.001),
   loss='binary_crossentropy'
)

# %%
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       2,097,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 32)                  │           4,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 32)                  │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │           4,224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_5 (Activation)            │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_6 (Activation)            │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 4096)                │       2,101,248 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,543,392 (17.33 MB)
#  Trainable params: 4,539,744 (17.32 MB)
#  Non-trainable params: 3,648 (14.25 KB)
